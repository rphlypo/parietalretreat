# %%
import os.path
import setup_data_paths
import numpy as np
from pandas import DataFrame, Series
import pandas

# %%
df = setup_data_paths.get_all_paths(root_dir="/home")
df
x = DataFrame({"region_ts": [np.random.normal(size=(len(list(df["anat"])))) for ii in range(len(list(df["anat"])))]}, index=df.index)
df = df.join(x)
df
# Out:
#             TR                                               anat  \
# hcp   0   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       1   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       2   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       3   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       4   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       5   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       6   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       7   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       8   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       9   0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       10  0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       11  0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
#       12  0.72  /home/storage/data/HCP/Q2/103414/MNINonLinear/...
# ...
