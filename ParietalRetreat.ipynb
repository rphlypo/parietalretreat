# %%
import os.path
import setup_data_paths
import numpy as np
from pandas import DataFrame, Series
import pandas

# %%
df = setup_data_paths.get_all_paths(root_dir="/home")
df
x = DataFrame({"region_signals": [np.random.normal(size=(len(list(df["anat"])))) for ii in range(len(list(df["anat"])))]}, index=df.index)
df = df.join(x)
df
# Out:
#            TR                                               anat  \
# ds105 0   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       1   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       2   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       3   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       4   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       5   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       6   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       7   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       8   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       9   2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       10  2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       11  2.5  /home/storage/workspace/brainpedia/preproc/ds1...
#       12  2.5  /home/storage/workspace/brainpedia/preproc/ds1...
# ...
